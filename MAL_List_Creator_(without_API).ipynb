# %% [markdown]
# <a href="https://colab.research.google.com/github/Victoryerz/9animetoMAL/blob/main/MAL_List_Creator_(without_API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing some packages
# !pip3 install dicttoxml
# !pip3 install xmltodict

# %%
from google.colab import files
import pandas as pd
from dicttoxml import dicttoxml
import xmltodict, json
import xml.etree.ElementTree as ET
from xml.dom import minidom
import time

# %%
uploaded = files.upload()

# Here you need to upload the 9anime export.txt file.
# It should contain MAL urls of the anime in your history.
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f35169fb-1804-433d-aa35-ce4f3efac59c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f35169fb-1804-433d-aa35-ce4f3efac59c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving export.txt to export.txt
# User uploaded file "export.txt" with length 22126 bytes

# %%
# Next, we access the MAL id(s) from the urls
NineAnimeList = pd.read_csv('./export.txt', names=['url'])
metaData = (NineAnimeList['url'].str.split('/')).apply(pd.Series)

anime = pd.DataFrame()

# The anime list dataset
anime['id'] = metaData[4] # this is all that we'll need.
anime['name'] = metaData[5]
anime['url'] = NineAnimeList['url']

# %%
# Here's how it should look
anime.head(2)
# Out:
#       id                name                                                url
# 0  28171  Shokugeki_no_Souma  http://myanimelist.net/anime/28171/Shokugeki_n...
# 1  38691            Dr_Stone        http://myanimelist.net/anime/38691/Dr_Stone

# %%
# Required fields for the XML file. All of methods go into the MAL class.
# If you know what you are doing feel free to edit the animeMeta dictionary.
# For example you can change the my_start_date and my_finish_date to today() or 
# import a separate series and feed it to the for loop inside the createDictList 
# function with a date argument added in animeDetails.

class MAL():
    def __init__(self, user_id, user_name):
        self.user_id = user_id
        self.user_name = user_name
        self.MALdict = None
        self.MALxml = None

    def animeDetails(self, id):
        animeMeta = {
            'series_animedb_id': id,
            'series_title': None,
            'series_type': None,
            'series_episodes': None,
            'my_id': 0,
            'my_watched_episodes': None,
            'my_start_date': '0000-00-00',
            'my_finish_date': '0000-00-00',
            'my_rated': None,
            'my_score': None,
            'my_storage': None,
            'my_storage_value': 0.00,
            'my_status': 'Completed',
            'my_comments': None,
            'my_times_watched': 0,
            'my_rewatch_value': None,
            'my_priority': 'LOW',
            'my_tags': None,
            'my_rewatching': 0,
            'my_rewatching_ep': 0,
            'my_discuss': 1,
            'my_sns': 'default',
            'update_on_import': 1}
        return animeMeta

    def createDictList(self, animeIDs):
        myinfo = {'user_id': self.user_id,
                  'user_name': self.user_name,
                  'user_export_type': '1',
                  'user_total_anime': len(animeIDs),
                  'user_total_watching': '0',
                  'user_total_completed': len(animeIDs),
                  'user_total_onhold': '0',
                  'user_total_dropped': '0',
                  'user_total_plantowatch': '0'}

        # Collecting all of the details json files into a single list
        anime = []
        for seriesID in animeIDs:
            anime.append(self.animeDetails(seriesID))

        # Constructing the main object
        MALdict = {
            'myanimelist': {
                'myinfo': myinfo,
                'anime': anime}}

        self.MALdict = MALdict
        return MALdict

    def dictToMALxml(self, animeDict):
        # Converts a dict into an MAL xml file
        def itemName(arg):
            return 'anime'

        # A small bug caused by the inherent differences between json and xml datatypes.
        # In json you can't reuse a key twice, while the same is not true for xml file.
        animeDict['myanimelist']['CustomRemoval'] = animeDict['myanimelist'].pop(
            'anime')

        xml = dicttoxml(animeDict['myanimelist'], root=True, custom_root='myanimelist', ids=False,
                        attr_type=False, item_func=itemName)

        # Removing a key due the json->xml bug
        xml = xml.replace(b'<CustomRemoval>', b'')
        xml = xml.replace(b'</CustomRemoval>', b'')

        MALxml = minidom.parseString(xml).toprettyxml(indent="  ")
        self.MALxml = MALxml
        return MALxml
    
    def createMALxml(self, animeIDs):
        self.createDictList(animeIDs)
        self.dictToMALxml(self.MALdict)
        return self.MALxml

# %%
# Usage

# You don't actually need to specify an id or a username. 
# As of now the site fixes the issue for you. So you can leave this as is.
mal = MAL(user_id='1234', user_name='John Joe')
MALxml = mal.createMALxml(anime['id'])

# Writting the MALxml into a file
with open("./MAL.xml", "w") as f:
    f.write(MALxml)

# Print to view the final output (or check the file directly)
# If you are in google colab click the folder icon on the right.
# You should see a file named MAL.xml on the left. Right click and download.
# Now go to https://myanimelist.net/import.php and upload the file.
# You are done!
print(MALxml)
# Out:
# <?xml version="1.0" ?>
# <myanimelist>
#   <myinfo>
#     <user_id>1234</user_id>
#     <user_name>John Joe</user_name>
#     <user_export_type>1</user_export_type>
#     <user_total_anime>368</user_total_anime>
#     <user_total_watching>0</user_total_watching>
#     <user_total_completed>368</user_total_completed>
#     <user_total_onhold>0</user_total_onhold>
#     <user_total_dropped>0</user_total_dropped>
#     <user_total_plantowatch>0</user_total_plantowatch>
#   </myinfo>
#   <anime>
#     <series_animedb_id>28171</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38691</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32182</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>2167</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40839</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>1735</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>15451</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40497</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>8425</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38830</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37926</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>11061</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37510</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>41353</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>5231</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32282</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40165</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38481</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>41389</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>969</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>2904</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>35847</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40417</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38680</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>4181</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37430</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32189</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>29786</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>3230</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38003</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40059</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>12979</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>136</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>8086</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>4654</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>20</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37086</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>35203</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>10800</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>39463</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>2251</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38408</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>1482</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>11617</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>18897</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>177</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37517</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37799</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>34662</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37345</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>42668</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>4382</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>355</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38735</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>5060</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40602</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32105</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>37576</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>40623</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>10620</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>23233</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>11933</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>31859</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32981</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>14075</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>41312</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
# ...
#   </anime>
#   <anime>
#     <series_animedb_id>28623</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>18139</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38256</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>1827</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>30296</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38555</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>38297</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>33478</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>2759</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>35076</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>25537</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>33049</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>10218</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>12115</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>12113</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>3785</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>32</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>35079</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>3784</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>226</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>11111</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
#   <anime>
#     <series_animedb_id>28999</series_animedb_id>
#     <series_title/>
#     <series_type/>
#     <series_episodes/>
#     <my_id>0</my_id>
#     <my_watched_episodes/>
#     <my_start_date>0000-00-00</my_start_date>
#     <my_finish_date>0000-00-00</my_finish_date>
#     <my_rated/>
#     <my_score/>
#     <my_storage/>
#     <my_storage_value>0.0</my_storage_value>
#     <my_status>Completed</my_status>
#     <my_comments/>
#     <my_times_watched>0</my_times_watched>
#     <my_rewatch_value/>
#     <my_priority>LOW</my_priority>
#     <my_tags/>
#     <my_rewatching>0</my_rewatching>
#     <my_rewatching_ep>0</my_rewatching_ep>
#     <my_discuss>1</my_discuss>
#     <my_sns>default</my_sns>
#     <update_on_import>1</update_on_import>
#   </anime>
# </myanimelist>

# %% [markdown]
# PS: It took me three hours to finish writing and implementing the code, but even so, mistakes aren't something we can intentionally prevent, so watch out for bugs.
